# %%
# 필수 데이터 분석 및 시각화, 백테스팅 라이브러리 설치
# !pip install pandas numpy plotly bt quantstats requests python-dotenv nbformat openai
# Out:
# Requirement already satisfied: pandas in ./.venv/lib/python3.14/site-packages (2.3.3)
# Requirement already satisfied: numpy in ./.venv/lib/python3.14/site-packages (2.3.5)
# Requirement already satisfied: plotly in ./.venv/lib/python3.14/site-packages (6.5.0)
# Requirement already satisfied: bt in ./.venv/lib/python3.14/site-packages (1.1.2)
# Requirement already satisfied: quantstats in ./.venv/lib/python3.14/site-packages (0.0.77)
# Requirement already satisfied: requests in ./.venv/lib/python3.14/site-packages (2.32.5)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.14/site-packages (1.2.1)
# Requirement already satisfied: nbformat in ./.venv/lib/python3.14/site-packages (5.10.4)
# Requirement already satisfied: openai in ./.venv/lib/python3.14/site-packages (2.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.14/site-packages (from pandas) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in ./.venv/lib/python3.14/site-packages (from plotly) (2.12.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.14/site-packages (from plotly) (25.0)
# Requirement already satisfied: ffn>=1.1.2 in ./.venv/lib/python3.14/site-packages (from bt) (1.1.2)
# Requirement already satisfied: pyprind>=2.11 in ./.venv/lib/python3.14/site-packages (from bt) (2.11.3)
# Requirement already satisfied: tqdm>=4 in ./.venv/lib/python3.14/site-packages (from bt) (4.67.1)
# Requirement already satisfied: seaborn>=0.11.0 in ./.venv/lib/python3.14/site-packages (from quantstats) (0.13.2)
# Requirement already satisfied: matplotlib>=3.3.0 in ./.venv/lib/python3.14/site-packages (from quantstats) (3.10.7)
# Requirement already satisfied: scipy>=1.7.0 in ./.venv/lib/python3.14/site-packages (from quantstats) (1.16.3)
# Requirement already satisfied: tabulate>=0.8.9 in ./.venv/lib/python3.14/site-packages (from quantstats) (0.9.0)
# Requirement already satisfied: yfinance>=0.2.65 in ./.venv/lib/python3.14/site-packages (from quantstats) (0.2.66)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.14/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.14/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.14/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.14/site-packages (from requests) (2025.11.12)
# Requirement already satisfied: fastjsonschema>=2.15 in ./.venv/lib/python3.14/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in ./.venv/lib/python3.14/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.14/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: traitlets>=5.1 in ./.venv/lib/python3.14/site-packages (from nbformat) (5.14.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./.venv/lib/python3.14/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./.venv/lib/python3.14/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.14/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in ./.venv/lib/python3.14/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in ./.venv/lib/python3.14/site-packages (from openai) (2.12.4)
# Requirement already satisfied: sniffio in ./.venv/lib/python3.14/site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in ./.venv/lib/python3.14/site-packages (from openai) (4.15.0)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.14/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: decorator>=5.0.7 in ./.venv/lib/python3.14/site-packages (from ffn>=1.1.2->bt) (5.2.1)
# Requirement already satisfied: scikit-learn>=0.15 in ./.venv/lib/python3.14/site-packages (from ffn>=1.1.2->bt) (1.7.2)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.29.0)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in ./.venv/lib/python3.14/site-packages (from matplotlib>=3.3.0->quantstats) (3.2.5)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.14/site-packages (from scikit-learn>=0.15->ffn>=1.1.2->bt) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.14/site-packages (from scikit-learn>=0.15->ffn>=1.1.2->bt) (3.6.0)
# Requirement already satisfied: multitasking>=0.0.7 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (0.0.12)
# Requirement already satisfied: frozendict>=2.3.4 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (4.14.2)
# Requirement already satisfied: curl_cffi>=0.7 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (6.33.1)
# Requirement already satisfied: websockets>=13.0 in ./.venv/lib/python3.14/site-packages (from yfinance>=0.2.65->quantstats) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in ./.venv/lib/python3.14/site-packages (from beautifulsoup4>=4.11.1->yfinance>=0.2.65->quantstats) (2.8)
# Requirement already satisfied: cffi>=1.12.0 in ./.venv/lib/python3.14/site-packages (from curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2.0.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.14/site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance>=0.2.65->quantstats) (2.23)

# %% [markdown]
# ## 0. KIS 환경 설정 & 공통 유틸
#
# ### 0-1. 환경변수 & 공통 헤더

# %%
from pathlib import Path
from datetime import datetime, timedelta

import json
import numpy as np
import pandas as pd
import plotly.express as px
import bt
import quantstats as qs
import requests
from openai import OpenAI

from kis.env import (
    ensure_kis_token,
    KIS_URL_BASE,
    get_api_headers,
    to_float,
    DATA_DIR,
)
from kis.meta import get_etf_name

client = OpenAI()

# %% [markdown]
# 현재 CSV를 DataFrame으로 읽기

# %%
def load_holdings_csv(path: str | Path = "holdings.csv") -> pd.DataFrame:
    """
    ETF 구성 종목 CSV를 표준 컬럼명으로 읽어오는 헬퍼.

    기대하는 원본 컬럼 (한국어):
      - 종목코드
      - 구성종목명
      - 주식수(계약수)
      - 평가금액
      - 시가총액
      - 시가총액 구성비중

    반환 DataFrame 컬럼 (영문):
      - isin
      - name
      - shares
      - valuation
      - market_cap
      - mcap_weight
    """
    path = Path(path)
    if not path.exists():
        raise FileNotFoundError(f"holdings CSV 파일을 찾을 수 없습니다: {path}")

    df = pd.read_csv(path)

    rename_map = {
        "종목코드": "isin",
        "구성종목명": "name",
        "주식수(계약수)": "shares",
        "평가금액": "valuation",
        "시가총액": "market_cap",
        "시가총액 구성비중": "mcap_weight",
    }
    df = df.rename(columns=rename_map)

    # 숫자 컬럼 정리 (쉼표 제거 후 float 변환)
    numeric_cols = ["shares", "valuation", "market_cap", "mcap_weight"]
    for col in numeric_cols:
        if col in df.columns:
            df[col] = df[col].map(to_float)

    return df


# 예시: 필요할 때 이런 식으로 호출
# holdings = load_holdings_csv("holdings.csv")
# holdings.head()
